# %% [markdown]
# <font color='darkred'> Unless otherwise noted, **this notebook will not be reviewed or autograded.**</font> You are welcome to use it for scratchwork, but **only the files listed in the exercises will be checked.**
#
# ---
#
# # Exercises
#
# For these exercises, you'll be creating a [Python class](https://www.geeksforgeeks.org/python/python-classes-and-objects/) in the *apputil.py* file.
#
# A few tips:
#
# - Some of these exercises will require some "JSON digging".
# - <font color='lightblue'>Your functions should still adhere to [best practices](https://codesignal.com/learn/courses/clean-code-basics-with-python/lessons/clean-function-design-in-python), so **your class should probably contain more functions than only the ones dictated below**.</font>

# %% [markdown]
# ## Exercise 1
#
# Create a Python class named `OpenMeteo` such that the following code initializes the object. Keep the `access_token` argument in the initializer for compatibility with earlier exercises, even though Open-Meteo itself does not require an API key for the endpoint used in this lab.
#
# ```python
# from apputil import OpenMeteo
#
# meteo = OpenMeteo(access_token="access_token")
# ```

# %% [markdown]
# ## Exercise 2
#
# Reference the `json_data` in the lab. Notice, when we geocode a location name (e.g., "Bloomington") in Open-Meteo, the result is a list of location dictionaries. Suppose we want to capture information for the most likely location match.
#
# Create a method for our `OpenMeteo` class called `.get_location(search_term)` which does the following:
#
# 1. Call the Open-Meteo geocoding endpoint with the `search_term`.
# 2. Extract the first location match from the `results` list.
# 3. **Return** that location dictionary.
#
# For example, the following code should return a dictionary of location information:
#
# ```python
# meteo.get_location("Bloomington")
# ```

# %% [markdown]
# ## Exercise 3
#
# Use the result from Exercise 2 to create another method for our `OpenMeteo` class called `.get_locations(search_terms)` (plural) which takes in a *list* of search terms, and returns a DataFrame containing a row for each search term, and the following columns:
#
# - `search_term`: the raw search term from `search_terms`
# - `location_name`: the (most likely) location name for the search term
# - `latitude`: latitude for that location
# - `longitude`: longitude for that location
#
# For example, the following should return a DataFrame with 4 rows:
#
# ```python
# meteo.get_locations(['Bloomington', 'Chicago', 'Seattle', 'Miami'])
# ```

# %% [markdown]
# ## Bonus Exercise (optional)
#
# 1. Gather a list of 100+ various location names, and save this list in a TXT file.
# 2. Write a Python *script* that saves the result of `.get_locations` for these locations in a CSV file.
# 3. If you have time, adjust this script to use multiprocessing.
